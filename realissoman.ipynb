# %%
import time

# %%
while True:    #타임슬립 한시간마다 돌릴 와일문 
    from selenium import webdriver as wb
    import time
    from bs4 import BeautifulSoup as bs
    import pandas as pd

    url = 'https://search.naver.com/search.naver?sm=top_hty&fbm=1&ie=utf8&query=%EB%A7%A8%ED%95%98%ED%83%84+%EB%82%A0%EC%94%A8'
    driver = wb.Chrome()
    driver.get(url)

    soup = bs(driver.page_source, 'lxml')



    for i in soup.select('#_cs_foreigninfo > div.c_body.tb > div > div.info_weath._daily_weather > div > p > span.todaytemp'):
        man_temp=int(i.text)

    for i in soup.select('#_cs_foreigninfo > div.c_body.tb > div > div.info_weath._daily_weather > div > ul > li:nth-child(2) > span:nth-child(1) > span'):
        man_rain=int(i.text)

    for i in soup.select('#_cs_foreigninfo > div.c_body.tb > div > div.info_weath._daily_weather > div > ul > li:nth-child(2) > span:nth-child(3) > span'):
        man_speed=int(i.text)

    for i in soup.select('#_cs_foreigninfo > div.c_body.tb > div > div.info_weath._daily_weather > div > ul > li:nth-child(2) > span:nth-child(5) > span'):
        man_hum=int(i.text)

    time.sleep(3)
    url = 'https://search.naver.com/search.naver?sm=tab_hty.top&where=nexearch&query=%EB%89%B4%EC%9A%95+%EB%B8%8C%EB%A3%A9%ED%81%B4%EB%A6%B0+%EB%82%A0%EC%94%A8&oquery=%EB%89%B4%EC%9A%95+%ED%80%B8+%EB%82%A0%EC%94%A8&tqi=UeEHUdp0YihsstnXlDlssssssSw-187319'

    driver.get(url)

    soup = bs(driver.page_source, 'lxml')

    for i in soup.select('#_cs_foreigninfo > div.c_body.tb > div > div.info_weath._daily_weather > div > p > span.todaytemp'):
        blo_temp=int(i.text)

    for i in soup.select('#_cs_foreigninfo > div.c_body.tb > div > div.info_weath._daily_weather > div > ul > li:nth-child(2) > span:nth-child(1) > span'):
        blo_rain=int(i.text)

    for i in soup.select('#_cs_foreigninfo > div.c_body.tb > div > div.info_weath._daily_weather > div > ul > li:nth-child(2) > span:nth-child(3) > span'):
        blo_speed=int(i.text)

    for i in soup.select('#_cs_foreigninfo > div.c_body.tb > div > div.info_weath._daily_weather > div > ul > li:nth-child(2) > span:nth-child(5) > span'):
        blo_hum=int(i.text)



    time.sleep(3)
    url = 'https://search.naver.com/search.naver?sm=tab_hty.top&where=nexearch&query=%EB%AF%B8%EA%B5%AD+%EB%89%B4%EC%9A%95+%ED%80%B8%EC%8A%A4+%EB%82%A0%EC%94%A8&oquery=%EB%AF%B8%EA%B5%AD+%EB%89%B4%EC%9A%95+%ED%80%B8%EC%A6%88&tqi=UeEIUlprvmsss6p%2BM%2B0ssssssy8-013650'

    driver.get(url)

    soup = bs(driver.page_source, 'lxml')

    for i in soup.select('#_cs_foreigninfo > div.c_body.tb > div > div.info_weath._daily_weather > div > p > span.todaytemp'):
        que_temp=int(i.text)

    for i in soup.select('#_cs_foreigninfo > div.c_body.tb > div > div.info_weath._daily_weather > div > ul > li:nth-child(2) > span:nth-child(1) > span'):
        que_rain=int(i.text)

    for i in soup.select('#_cs_foreigninfo > div.c_body.tb > div > div.info_weath._daily_weather > div > ul > li:nth-child(2) > span:nth-child(3) > span'):
        que_speed=int(i.text)

    for i in soup.select('#_cs_foreigninfo > div.c_body.tb > div > div.info_weath._daily_weather > div > ul > li:nth-child(2) > span:nth-child(5) > span'):
        que_hum=int(i.text)

    que_hum

    time.sleep(3)
    url = 'https://search.naver.com/search.naver?sm=tab_hty.top&where=nexearch&query=%EB%AF%B8%EA%B5%AD+%EB%89%B4%EC%9A%95+%EB%B8%8C%EB%A1%B1%ED%81%AC%EC%8A%A4+%EB%82%A0%EC%94%A8&oquery=%EB%AF%B8%EA%B5%AD+%EB%89%B4%EC%9A%95+%ED%80%B8%EC%8A%A4+%EB%82%A0%EC%94%A8&tqi=UeEIQlprvOsssLM8aFlssssssb8-094837'

    driver.get(url)

    soup = bs(driver.page_source, 'lxml')

    for i in soup.select('#_cs_foreigninfo > div.c_body.tb > div > div.info_weath._daily_weather > div > p > span.todaytemp'):
        bro_temp=int(i.text)

    for i in soup.select('#_cs_foreigninfo > div.c_body.tb > div > div.info_weath._daily_weather > div > ul > li:nth-child(2) > span:nth-child(1) > span'):
        bro_rain=int(i.text)

    for i in soup.select('#_cs_foreigninfo > div.c_body.tb > div > div.info_weath._daily_weather > div > ul > li:nth-child(2) > span:nth-child(3) > span'):
        bro_speed=int(i.text)

    for i in soup.select('#_cs_foreigninfo > div.c_body.tb > div > div.info_weath._daily_weather > div > ul > li:nth-child(2) > span:nth-child(5) > span'):
        bro_hum=int(i.text)
    time.sleep(3)
    url = 'https://search.naver.com/search.naver?sm=tab_hty.top&where=nexearch&query=%EB%AF%B8%EA%B5%AD+%EB%89%B4%EC%9A%95+%EC%8A%A4%ED%83%9C%ED%8A%BC%EC%95%84%EC%9D%BC%EB%9E%9C%EB%93%9C+%EB%82%A0%EC%94%A8&oquery=%EB%AF%B8%EA%B5%AD+%EB%89%B4%EC%9A%95+%EB%B8%8C%EB%A1%B1%ED%81%AC%EC%8A%A4+%EB%82%A0%EC%94%A8&tqi=UeEIYdprvxsssRi2mWdssssstER-291099'

    driver.get(url)

    soup = bs(driver.page_source, 'lxml')

    for i in soup.select('#_cs_foreigninfo > div.c_body.tb > div > div.info_weath._daily_weather > div > p > span.todaytemp'):
        sta_temp=int(i.text)

    for i in soup.select('#_cs_foreigninfo > div.c_body.tb > div > div.info_weath._daily_weather > div > ul > li:nth-child(2) > span:nth-child(1) > span'):
        sta_rain=int(i.text)

    for i in soup.select('#_cs_foreigninfo > div.c_body.tb > div > div.info_weath._daily_weather > div > ul > li:nth-child(2) > span:nth-child(3) > span'):
        sta_speed=int(i.text)

    for i in soup.select('#_cs_foreigninfo > div.c_body.tb > div > div.info_weath._daily_weather > div > ul > li:nth-child(2) > span:nth-child(5) > span'):
        sta_hum=int(i.text)

    from datetime import datetime 
    now = datetime.now()


    import folium

    from folium.plugins import MarkerCluster

    mc = MarkerCluster()

    import pandas as pd

    from sklearn.externals import joblib
    from folium import plugins

    model=joblib.load('realfinalized_model.sav')

    NY_police=pd.read_csv('NYPD.csv')

    street_info=pd.read_csv('street.csv',index_col='Unnamed: 0')

    import json

    map_osm = folium.Map(location=[40.717307, -73.986919])
    rfile = open('Police Precincts.geojson','r')
    jsonData = json.load(rfile)
    folium.GeoJson(jsonData, name='json_data').add_to(map_osm)

    for i in range(77):
        folium.Marker(location=[NY_police['Li'][i],NY_police['La'][i]],popup=NY_police[' Precinct'][i],icon=folium.Icon(color='red',icon='star')).add_to(map_osm)

    vc=pd.read_csv('X_train.csv',encoding='euc-kr',index_col='Unnamed: 0')

    columns=[
    '온도',
    '강수량',
    '상대습도',
    '풍속',
    'month',
    'day',
    'hour',
    '1 AVE',
    '1 ST',
    '10 AVE',
    '10 ST',
    '100 AVE',
    '100 DR',
    '101 AVE',
    '101 ST',
    '102 AVE',
    '102 RD',
    '103 AVE',
    '103 RD',
    '104 AVE',
    '104 ST',
    '105 AVE',
    '105 ST',
    '106 AVE',
    '106 RD',
    '106 ST',
    '107 AVE',
    '107 ST',
    '108 AVE',
    '108 DR',
    '109 AVE',
    '109 RD',
    '11 AVE',
    '11 ST',
    '110 AVE',
    '110 RD',
    '111 AVE',
    '111 RD',
    '111 ST',
    '112 AVE',
    '112 RD',
    '113 AVE',
    '113 DR',
    '113 RD',
    '114 AVE',
    '114 PL',
    '114 RD',
    '115 AVE',
    '115 DR',
    '115 RD',
    '116 AVE',
    '116 DR',
    '116 RD',
    '116 ST',
    '118 AVE',
    '118 RD',
    '119 AVE',
    '119 RD',
    '12 AVE',
    '12 ST',
    '120 AVE',
    '122 AVE',
    '123 AVE',
    '123 ST',
    '124 AVE',
    '125 AVE',
    '125 ST',
    '126 ST',
    '127 AVE',
    '128 AVE',
    '129 AVE',
    '129 ST',
    '13 AVE',
    '13 ST',
    '130 AVE',
    '130 ST',
    '131 AVE',
    '133 AVE',
    '134 AVE',
    '134 RD',
    '135 AVE',
    '135 PL',
    '135 ST',
    '136 AVE',
    '136 RD',
    '137 AVE',
    '137 RD',
    '14 AVE',
    '14 RD',
    '14 ST',
    '140 AVE',
    '141 AVE',
    '142 AVE',
    '143 RD',
    '144 AVE',
    '144 DR',
    '145 AVE',
    '146 AVE',
    '147 AVE',
    '147 ST',
    '148 DR',
    '149 PL',
    '15 AVE',
    '15 DR',
    '150 ST',
    '153 ST',
    '159 RD',
    '16 AVE',
    '16 RD',
    '16 ST',
    '161 AVE',
    '164 AVE',
    '164 RD',
    '17 AVE',
    '17 ST',
    '18 AVE',
    '182 ST',
    '184 ST',
    '186 LN',
    '19 AVE',
    '2 AVE',
    '2 ST',
    '20 AVE',
    '20 ST',
    '21 AVE',
    '21 ST',
    '218 ST',
    '219 ST',
    '22 AVE',
    '22 ST',
    '220 ST',
    '221 ST',
    '224 ST',
    '225 ST',
    '226 ST',
    '227 ST',
    '228 ST',
    '23 AVE',
    '23 RD',
    '23 ST',
    '230 ST',
    '232 ST',
    '24 AVE',
    '24 ST',
    '243 ST',
    '247 ST',
    '26 AVE',
    '26 ST',
    '27 AVE',
    '27 ST',
    '28 ST',
    '29 AVE',
    '29 ST',
    '3 AVE',
    '3 ST',
    '30 DR',
    '30 RD',
    '30 ST',
    '31 AVE',
    '32 AVE',
    '32 ST',
    '33 AVE',
    '33 RD',
    '33 ST',
    '34 AVE',
    '34 RD',
    '34 ST',
    '35 AVE',
    '35 ST',
    '36 ST',
    '37 AVE',
    '37 DR',
    '37 RD',
    '37 ST',
    '38 AVE',
    '38 ST',
    '39 AVE',
    '4 AVE',
    '4 ST',
    '40 AVE',
    '40 DR',
    '40 RD',
    '40 ST',
    '41 AVE',
    '41 DR',
    '41 ST',
    '42 AVE',
    '42 ST',
    '43 AVE',
    '43 RD',
    '43 ST',
    '44 AVE',
    '44 ST',
    '45 AVE',
    '45 DR',
    '45 ST',
    '46 AVE',
    '46 ST',
    '47 AVE',
    '47 ST',
    '48 AVE',
    '49 AVE',
    '49 ST',
    '5 AVE',
    '50 AVE',
    '51 AVE',
    '51 ST',
    '52 AVE',
    '52 DR',
    '52 RD',
    '53 AVE',
    '53 ST',
    '54 AVE',
    '54 ST',
    '55 AVE',
    '55 RD',
    '55 ST',
    '56 AVE',
    '56 DR',
    '56 RD',
    '56 ST',
    '57 AVE',
    '57 DR',
    '57 RD',
    '58 AVE',
    '58 DR',
    '58 PL',
    '58 RD',
    '58 ST',
    '59 AVE',
    '59 DR',
    '59 RD',
    '59 ST',
    '6 AVE',
    '6 RD',
    '60 AVE',
    '60 DR',
    '60 LN',
    '60 PL',
    '60 RD',
    '60 ST',
    '61 RD',
    '61 ST',
    '62 AVE',
    '62 RD',
    '62 ST',
    '63 AVE',
    '63 DR',
    '63 RD',
    '63 ST',
    '64 AVE',
    '64 RD',
    '64 ST',
    '65 AVE',
    '65 LN',
    '65 RD',
    '66 DR',
    '66 RD',
    '66 ST',
    '67 AVE',
    '67 DR',
    '67 RD',
    '67 ST',
    '68 AVE',
    '68 RD',
    '68 ST',
    '69 AVE',
    '69 RD',
    '7 AVE',
    '70 AVE',
    '71 AVE',
    '71 RD',
    '71 ST',
    '72 AVE',
    '72 DR',
    '72 RD',
    '72 ST',
    '74 AVE',
    '74 ST',
    '75 AVE',
    '75 RD',
    '75 ST',
    '76 AVE',
    '76 RD',
    '76 ST',
    '77 AVE',
    '77 ST',
    '78 AVE',
    '78 RD',
    '78 ST',
    '79 AVE',
    '79 LN',
    '79 ST',
    '8 AVE',
    '8 ST',
    '80 ST',
    '81 AVE',
    '81 RD',
    '82 AVE',
    '82 ST',
    '83 ST',
    '84 RD',
    '85 AVE',
    '85 DR',
    '85 RD',
    '85 ST',
    '86 AVE',
    '86 RD',
    '87 AVE',
    '87 DR',
    '87 RD',
    '87 ST',
    '88 AVE',
    '88 DR',
    '88 RD',
    '89 AVE',
    '89 ST',
    '9 AVE',
    '9 ST',
    '90 AVE',
    '90 RD',
    '91 AVE',
    '91 RD',
    '92 AVE',
    '93 AVE',
    '93 RD',
    '94 AVE',
    '94 RD',
    '94 ST',
    '95 AVE',
    '95 ST',
    '97 AVE',
    '97 ST',
    '99 AVE',
    '99 RD',
    'ADAM CLAYTON POWELL JR BLVD',
    'ADEE AVE',
    'ADMIRAL LN',
    'AINSLIE ST',
    'ALBANY AVE',
    'ALBEMARLE RD',
    'ALEX CIR',
    'ALICE CT',
    'ALLEN AVE',
    'ALLEN PL',
    'ALLEN ST',
    'ALMEDA AVE',
    'ALSTYNE AVE',
    'ALTON PL',
    'AMBOY RD',
    'AMITY ST',
    'AMSTEL BLVD',
    'AMSTERDAM AVE',
    'ANDERSON AVE',
    'ANDREWS AVE',
    'ANDREWS AVE N',
    'ANDREWS AVE S',
    'ANN ST',
    'ANTHONY AVE',
    'ANTHONY ST',
    'APPLEGATE CT',
    'ARCADIA PL',
    'ARCHER AVE',
    'ARIELLE LN',
    'ARION PL',
    'ARLINGTON AVE',
    'ARLINGTON PL',
    'ARLINGTON TER',
    'ARNOLD AVE',
    'ARNOLD ST',
    'ARNOW AVE',
    'ARTHUR AVE',
    'ARTHUR KILL RD',
    'ASHBY AVE',
    'ASHFORD ST',
    'ASHLEY LN',
    'ASKE ST',
    'ASTER CT',
    'ASTORIA BLVD',
    'ATLANTIC AVE',
    'ATTORNEY ST',
    'AUDUBON AVE',
    'AUSTIN ST',
    'AUTUMN AVE',
    'AVE A',
    'AVE B',
    'AVE C',
    'AVE D',
    'AVE H',
    'AVE I',
    'AVE K',
    'AVE L',
    'AVE M',
    'AVE N',
    'AVE O',
    'AVE OF THE AMERICAS',
    'AVE R',
    'AVE S',
    'AVE T',
    'AVE U',
    'AVE V',
    'AVE W',
    'AVE X',
    'AVE Y',
    'AVE Z',
    'AVERY AVE',
    'AVON PL',
    'AZTEC PL',
    'BAINBRIDGE AVE',
    'BAINBRIDGE ST',
    'BAISLEY AVE',
    'BAISLEY BLVD',
    'BAKER AVE',
    'BALFOUR PL',
    'BALSAM PL',
    'BALTIC ST',
    'BANK ST',
    'BAR CT',
    'BARBEY ST',
    'BARNES AVE',
    'BARROW ST',
    'BARRY CT',
    'BARTLETT PL',
    'BASSFORD AVE',
    'BATTERY PL',
    'BAUGHMAN PL',
    'BAXTER ST',
    'BAY 10 ST',
    'BAY 11 ST',
    'BAY 14 ST',
    'BAY 16 ST',
    'BAY 17 ST',
    'BAY 20 ST',
    'BAY 23 ST',
    'BAY 26 ST',
    'BAY 28 ST',
    'BAY 32 ST',
    'BAY 34 ST',
    'BAY 37 ST',
    'BAY 44 ST',
    'BAY 50 ST',
    'BAY 7 ST',
    'BAY 8 ST',
    'BAY PKWY',
    'BAY RIDGE AVE',
    'BAY ST',
    'BAY VIEW PL',
    'BAYARD ST',
    'BCH 116 ST',
    'BCH 17 ST',
    'BCH 20 ST',
    'BCH 24 ST',
    'BCH 25 ST',
    'BCH 45 ST',
    'BCH 46 ST',
    'BCH CHANNEL DR',
    'BEACH AVE',
    'BEACH PL',
    'BEACH ST',
    'BEACON CT',
    'BEAUMONT AVE',
    'BECK ST',
    'BEDELL LN',
    'BEDFORD AVE',
    'BEDFORD ST',
    'BEECH AVE',
    'BEEKMAN AVE',
    'BEEKMAN PL',
    'BELAIR LN',
    'BELAIR RD',
    'BELL ST',
    'BELMONT AVE',
    'BENEDICT AVE',
    'BENJAMIN DR',
    'BENSON AVE',
    'BENSON ST',
    'BENTLEY LN',
    'BENZIGER AVE',
    'BERGEN PL',
    'BERGEN ST',
    'BERRIMAN ST',
    'BERRY ST',
    'BEVERLEY RD',
    'BEVERLY AVE',
    'BEVY CT',
    'BIDWELL AVE',
    'BILLINGSLEY TER',
    'BLACKROCK AVE',
    'BLAKE AVE',
    'BLEECKER ST',
    'BLOSSOM AVE',
    'BOERUM ST',
    'BOND ST',
    'BOONE AVE',
    'BOSTON RD',
    'BOWERY',
    'BRADDOCK AVE',
    'BRADLEY CT',
    'BRADY AVE',
    'BREWSTER ST',
    'BRIGGS AVE',
    'BRIGHTON 1',
    'BRIGHTON 1 CT',
    'BRIGHTON 1 LN',
    'BRIGHTON 1 PATH',
    'BRIGHTON 1 RD',
    'BRIGHTON 1 TER',
    'BRIGHTON 10 CT',
    'BRIGHTON 10 LN',
    'BRIGHTON 10 PATH',
    'BRIGHTON 10 ST',
    'BRIGHTON 10 TER',
    'BRIGHTON 12 ST',
    'BRIGHTON 13 ST',
    'BRIGHTON 14 ST',
    'BRIGHTON 2',
    'BRIGHTON 2 LN',
    'BRIGHTON 2 ST',
    'BRIGHTON 3 ST',
    'BRIGHTON 5 PL',
    'BRIGHTON 8 CT',
    'BRIGHTON AVE',
    'BRIGHTON CT',
    'BRIGHTWATER CT',
    'BRITTON AVE',
    'BROAD ST',
    'BROADWAY',
    'BRONX BLVD',
    'BRONX PARK AVE',
    'BROOK ST',
    'BROOKHAVEN AVE',
    'BROOKLYN AVE',
    'BROOME ST',
    'BROWN PL',
    'BRUCKNER BLVD',
    'BRUNO LN',
    'BRYANT AVE',
    'BRYANT PARK',
    'BURCHELL AVE',
    'BURCHELL RD',
    'BURKE AVE',
    'BUTLER PL',
    'BUTLER ST',
    'BYRON AVE',
    'CALDWELL AVE',
    'CALYER ST',
    'CAMBRELENG AVE',
    'CAMERON AVE',
    'CAMPBELL AVE',
    'CAMPUS PL',
    'CANAL PL',
    'CANAL ST',
    'CANTON CT',
    'CARLTON AVE',
    'CARMINE ST',
    'CARNEGIE AVE',
    'CAROL PL',
    'CARPENTER AVE',
    'CARROLL PL',
    'CARROLL ST',
    'CARTER AVE',
    'CARY AVE',
    'CASTLETON AVE',
    'CATALPA AVE',
    'CATON AVE',
    'CEBRA AVE',
    'CECIL CT',
    'CEDAR AVE',
    'CELESTE CT',
    'CENTER ST',
    'CENTRAL AVE',
    'CENTRAL PARK  W',
    'CENTRE ST',
    'CENTREVILLE ST',
    'CHANDLER ST',
    'CHARLES AVE',
    'CHARLES ST',
    'CHARLESTON AVE',
    'CHATTERTON AVE',
    'CHAUNCEY ST',
    'CHENEY ST',
    'CHERRY AVE',
    'CHERRYWOOD CT',
    'CHESTER CT',
    'CHESTER ST',
    'CHESTNUT AVE',
    'CHESTNUT CIR',
    'CHESTNUT ST',
    'CHRISTIE AVE',
    'CHRISTOPHER ST',
    'CHRYSTIE ST',
    'CHURCH AVE',
    'CHURCH RD',
    'CLARKSON AVE',
    'CLASSON AVE',
    'CLAY AVE',
    'CLEVELAND ST',
    'CLIFTON AVE',
    'CLIFTON PL',
    'CLINTON AVE',
    'CLINTON ST',
    'CLOVE LAKE PLACE',
    'CODDINGTON AVE',
    'COLD SPRING RD',
    'COLDEN AVE',
    'COLLIER AVE',
    'COLONY AVE',
    'COLUMBIA HTS',
    'COMMERCE ST',
    'CONCORD ST',
    'CONCOURSE VLG W',
    'CONGRESS ST',
    'CONOVER ST',
    'CONSELYEA ST',
    'CONVENT AVE',
    'CONWAY ST',
    'COOK ST',
    'COOPER AVE',
    'COOPER ST',
    'CORNAGA AVE',
    'CORNELIA ST',
    'CORNELL AVE',
    'CORONA AVE',
    'CORSON AVE',
    'CORTELYOU RD',
    'CORTLANDT ST',
    'COUNTRY DR E',
    'COUNTRY POINTE CIR',
    'COURSEN PL',
    'COURT ST',
    'COVE CT',
    'CRABTREE AVE',
    'CRANBERRY CT',
    'CRANDALL AVE',
    'CRANFORD AVE',
    'CRAWFORD AVE',
    'CRESCENT AVE',
    'CRESCENT ST',
    'CRESTON AVE',
    'CROCHERON AVE',
    'CROES PL',
    'CROOKE AVE',
    'CROSBY ST',
    'CROSS BAY BLVD',
    'CROSS BRONX EXPY',
    'CROSS ISLAND PARKWAY SR NORTH',
    'CROWN ST',
    'CUBA AVE',
    'CURTIS PL',
    'CURZON RD',
    'CYPRESS AVE',
    'CYPRESS CT',
    'CYRUS AVE',
    'DAFFODIL CT',
    'DALIAN CT',
    'DALY AVE',
    'DANIEL ST',
    'DAVENPORT AVE',
    'DAVIDSON AVE',
    'DAVIS CT',
    'DAWSON ST',
    'DAYNA DR',
    'DE GROOT PL',
    'DE SALES PL',
    'DE WITT AVE',
    'DEAN ST',
    'DEBBIE ST',
    'DECATUR AVE',
    'DECATUR ST',
    'DEERFIELD RD',
    'DEKALB AVE',
    'DELAFIELD AVE',
    'DELAWARE AVE',
    'DENIS ST',
    'DEPOT RD',
    'DESTINY CT',
    'DEVOE ST',
    'DEVOE TER',
    'DEWEY AVE',
    'DITMAS AVE',
    'DIVISION AVE',
    'DIVISION PL',
    'DIVISION ST',
    'DOE PL',
    'DONGAN AVE',
    'DORAN AVE',
    'DORSEY ST',
    'DOUGLAS AVE',
    'DOVER GRN',
    'DOWNING ST',
    'DOYERS ST',
    'DR M L KING JR BLVD',
    'DREW ST',
    'DRIGGS AVE',
    'DRY HARBOR RD',
    'DUDLEY AVE',
    'DULANCEY CT',
    'DUMONT AVE',
    'DUNE CT',
    'DUPONT ST',
    'DURYEA CT',
    'DWIGHT ST',
    'E  1 ST',
    'E  10 ST',
    'E  100 ST',
    'E  101 ST',
    'E  109 ST',
    'E  11 ST',
    'E  117 ST',
    'E  118 ST',
    'E  12 ST',
    'E  120 ST',
    'E  126 ST',
    'E  127 ST',
    'E  134 ST',
    'E  139 ST',
    'E  143 ST',
    'E  145 ST',
    'E  147 ST',
    'E  148 ST',
    'E  152 ST',
    'E  154 ST',
    'E  155 ST',
    'E  156 ST',
    'E  157 ST',
    'E  158 ST',
    'E  159 ST',
    'E  160 ST',
    'E  162 ST',
    'E  163 ST',
    'E  164 ST',
    'E  165 ST',
    'E  166 ST',
    'E  167 ST',
    'E  168 ST',
    'E  169 ST',
    'E  17 ST',
    'E  170 ST',
    'E  172 ST',
    'E  173 ST',
    'E  174 ST',
    'E  175 ST',
    'E  176 ST',
    'E  177 ST',
    'E  178 ST',
    'E  18 ST',
    'E  180 ST',
    'E  181 ST',
    'E  182 ST',
    'E  183 ST',
    'E  185 ST',
    'E  187 ST',
    'E  188 ST',
    'E  194 ST',
    'E  196 ST',
    'E  197 ST',
    'E  203 ST',
    'E  205 ST',
    'E  211 ST',
    'E  216 ST',
    'E  217 ST',
    'E  22 ST',
    'E  221 ST',
    'E  226 ST',
    'E  227 ST',
    'E  228 ST',
    'E  230 ST',
    'E  232 ST',
    'E  234 ST',
    'E  235 ST',
    'E  236 ST',
    'E  237 ST',
    'E  238 ST',
    'E  239 ST',
    'E  240 ST',
    'E  241 ST',
    'E  243 ST',
    'E  26 ST',
    'E  27 ST',
    'E  28 ST',
    'E  3 ST',
    'E  30 ST',
    'E  32 ST',
    'E  34 ST',
    'E  36 ST',
    'E  37 ST',
    'E  38 ST',
    'E  4 ST',
    'E  40 ST',
    'E  43 ST',
    'E  44 ST',
    'E  45 ST',
    'E  47 ST',
    'E  48 ST',
    'E  5 ST',
    'E  51 ST',
    'E  53 ST',
    'E  54 ST',
    'E  55 ST',
    'E  57 ST',
    'E  59 ST',
    'E  6 RD',
    'E  60 ST',
    'E  63 ST',
    'E  64 ST',
    'E  65 ST',
    'E  66 ST',
    'E  68 ST',
    'E  69 ST',
    'E  7 ST',
    'E  71 ST',
    'E  73 ST',
    'E  74 ST',
    'E  75 ST',
    'E  76 ST',
    'E  77 ST',
    'E  78 ST',
    'E  8 ST',
    'E  80 ST',
    'E  81 ST',
    'E  82 ST',
    'E  83 ST',
    'E  84 ST',
    'E  85 ST',
    'E  86 ST',
    'E  88 ST',
    'E  89 ST',
    'E  91 ST',
    'E  92 ST',
    'E  94 ST',
    'E  95 ST',
    'E  99 ST',
    'E  BRANDIS AVE',
    'E  BROADWAY',
    'E  FORDHAM RD',
    'E  MT EDEN AVE',
    'E  NEW YORK AVE',
    'E  TREMONT AVE',
    'EAGLE AVE',
    'EATON CT',
    'EBEY LN',
    'EBONY CT',
    'EDGECOMBE AVE',
    'EDGEWATER PARK',
    'EDGEWOOD RD',
    'EDMORE AVE',
    'EDWARD L GRANT HWY',
    'EGGERT PL',
    'ELDERT LN',
    'ELDERT ST',
    'ELDRIDGE ST',
    'ELEANOR PL',
    'ELIZABETH ST',
    'ELKS RD',
    'ELLERY ST',
    'ELLIOT PL',
    'ELLIS AVE',
    'ELMHURST AVE',
    'ELTON AVE',
    'EMMONS AVE',
    'EMPIRE BLVD',
    'ERASMUS ST',
    'ERIKA LOOP',
    'ESSEX ST',
    'ETNA ST',
    'EVANS ST',
    'FAIRMOUNT AVE',
    'FAIRVIEW AVE',
    'FARRAGUT RD',
    'FAY CT',
    'FAYETTE ST',
    'FEARN PL',
    'FEATHERBED LN',
    'FENIMORE ST',
    'FERN PL',
    'FERNDALE AVE',
    'FILLMORE AVE',
    'FILLMORE PL',
    'FINDLAY AVE',
    'FINGERBOARD RD',
    'FLATBUSH AVE',
    'FLATLANDS 4 ST',
    'FLATLANDS 7 ST',
    'FLATLANDS AVE',
    'FLOYD ST',
    'FLUSHING AVE',
    'FOCH BLVD',
    'FORD ST',
    'FOREST AVE',
    'FOREST GRN',
    'FOREST LN',
    'FORLEY ST',
    'FORREST ST',
    'FOSTER AVE',
    'FOX ST',
    'FRANCINE CT',
    'FRANKLIN AVE',
    'FRANKLIN ST',
    'FREDERICK DOUGLASS BLVD',
    'FREEBORN ST',
    'FREEMAN ST',
    'FRIEL PL',
    'FRONT ST',
    'FROST ST',
    'FT CHARLES PL',
    'FT HAMILTON PKWY',
    'FULTON AVE',
    'FULTON ST',
    'FURMAN AVE',
    'GARDEN PL',
    'GARY ST',
    'GATES AVE',
    'GATLING PL',
    'GAULDY AVE',
    'GELSTON AVE',
    'GEORGIA AVE',
    'GERARD AVE',
    'GERRY ST',
    'GIFFORD AVE',
    'GILBERT PL',
    'GILMORE CT',
    'GIORDAN CT',
    'GIVAN AVE',
    'GLASSBORO AVE',
    'GLEASON AVE',
    'GLEN ST',
    'GLENMORE AVE',
    'GLENWOOD RD',
    'GOLD ST',
    'GORDON ST',
    'GOUVERNEUR AVE',
    'GRACE RD',
    'GRAHAM AVE',
    'GRAND AVE',
    'GRAND CENTRAL PARKWAY SR NORTH',
    'GRAND ST',
    'GRANITE ST',
    'GRANT AVE',
    'GRANT ST',
    'GRASMERE CT',
    'GRASSMERE TER',
    'GRAVESEND NECK RD',
    'GREEN ST',
    'GREENCROFT AVE',
    'GREENE AVE',
    'GREENE ST',
    'GREENPOINT AVE',
    'GREENWOOD AVE',
    'GREYSTONE AVE',
    'GRIMSBY ST',
    'GRISWOLD AVE',
    'GROTON ST',
    'GROVE AVE',
    'GROVE ST',
    'GUY R BREWER BLVD',
    'HALPERIN AVE',
    'HALSEY ST',
    'HAMILTON PL',
    'HAMILTON ST',
    'HAMILTON TER',
    'HAMPTON GRN',
    'HANCOCK ST',
    'HANOVER AVE',
    'HANSON PL',
    'HARBOR LOOP',
    'HARDING PARK',
    'HARDY ST',
    'HARMAN ST',
    'HARRISON AVE',
    'HARRISON ST',
    'HART ST',
    'HASKIN ST',
    'HAVEMEYER ST',
    'HAVEN AVE',
    'HAWKSTONE ST',
    'HEALY AVE',
    'HEBERTON AVE',
    'HEGEMAN AVE',
    'HEMLOCK LN',
    'HENDERSON AVE',
    'HENRY ST',
    'HERKIMER ST',
    'HERMANY AVE',
    'HERZL ST',
    'HESSLER AVE',
    'HESTER ST',
    'HEWES ST',
    'HEYWARD ST',
    'HICKS ST',
    'HIGHLAND PL',
    'HILL ST',
    'HILLEL PL',
    'HILLSIDE AVE',
    'HIMROD ST',
    'HOE AVE',
    'HOFFMAN ST',
    'HOLLAND AVE',
    'HOLLIS AVE',
    'HOLLY ST',
    'HOLMES LN',
    'HOME ST',
    'HOMER AVE',
    'HONE AVE',
    'HOOPER ST',
    'HOOVER AVE',
    'HOPE ST',
    'HORACE HARDING EXPRESSWAY SR N',
    'HOWARD AVE',
    'HOWARD ST',
    'HOYT ST',
    'HUDSON',
    'HUGHES AVE',
    'HULL AVE',
    'HULL ST',
    'HUMBOLDT ST',
    'HUNT AVE',
    'HUNTER ST',
    'HURON ST',
    'HYLAN BLVD',
    'HYMEN CT',
    'ILYSSA WAY',
    'INDEPENDENCE AVE',
    'INDIA ST',
    'INGRAHAM ST',
    'INNIS ST',
    'INWOOD AVE',
    'INWOOD ST',
    'IRVING AVE',
    'IRVING PL',
    'JACKSON AVE',
    'JACKSON ST',
    'JAMAICA AVE',
    'JAMES CT',
    'JASMINE AVE',
    'JAVA ST',
    'JAY AVE',
    'JAY ST',
    'JEFFERSON AVE',
    'JEFFERSON PL',
    'JEFFERSON ST',
    'JENNINGS ST',
    'JEROME AVE',
    'JEROME ST',
    'JERSEY ST',
    'JOHN ST',
    'JOHNSON AVE',
    'JONES ST',
    'JORALEMON ST',
    'JORDAN AVE',
    'KALMIA AVE',
    'KANE ST',
    'KATAN AVE',
    'KATHLEEN CT',
    'KAUFMAN PL',
    'KEEL CT',
    'KENMORE ST',
    'KENT AVE',
    'KENT ST',
    'KERMIT PL',
    'KETCHAM ST',
    'KIELY PL',
    'KINGS HWY',
    'KINGSBRIDGE TER',
    'KINGSBURY AVE',
    'KINGSLEY AVE',
    'KINGSTON AVE',
    'KINSELLA ST',
    'KISWICK ST',
    'KNESEL ST',
    'KNICKERBOCKER AVE',
    'KOSCIUSZKO ST',
    'KOSSUTH AVE',
    'KRIER PL',
    'KRISSA CT',
    'LA SALLE AVE',
    'LAFAYETTE',
    'LAFAYETTE AVE',
    'LAFAYETTE ST',
    'LAFORGE PL',
    'LAIGHT ST',
    'LAKE PL',
    'LAKEWOOD AVE',
    'LAMA CT',
    'LAMONT AVE',
    'LANCASTER AVE',
    'LANDIS CT',
    'LAREDO AVE',
    'LARKIN ST',
    'LARUE AVE',
    'LATOURETTE LN',
    'LAUREL AVE',
    'LAURIE AVE',
    'LAWTON AVE',
    'LEFFERTS BLVD',
    'LENHART ST',
    'LENOX RD',
    'LEONARD ST',
    'LEROY ST',
    'LETTY CT',
    'LEVERETT AVE',
    'LEWIS AVE',
    'LEWMAY RD',
    'LEXINGTON AVE',
    'LIBERTY AVE',
    'LIBERTY ST',
    'LIEBIG AVE',
    'LILLIE LN',
    'LINCOLN PL',
    'LINCOLN RD',
    'LINCOLN ST',
    'LINDA LN',
    'LINDEN BLVD',
    'LINDEN ST',
    'LIVONIA AVE',
    'LOCKE AVE',
    'LOCUST ST',
    'LOGAN ST',
    'LONGFELLOW AVE',
    'LORILLARD PL',
    'LORIMER ST',
    'LORING PL S',
    'LOTT AVE',
    'LOTT LN',
    'LOUISA ST',
    'LOWE CT',
    'LOWELL ST',
    'LUCILLE AVE',
    'LUDLOW ST',
    'LUQUER ST',
    'LURTING AVE',
    'LYDIG AVE',
    'LYNCH ST',
    'LYNDALE LN',
    'MAC DONOUGH ST',
    'MAC DOUGAL ST',
    'MACLAY AVE',
    'MACON ST',
    'MADAN CT',
    'MADISON AVE',
    'MADISON ST',
    'MAGENTA ST',
    'MAIN ST',
    'MANHATTAN AVE',
    'MANHATTAN CT',
    'MANNING ST',
    'MANOR RD',
    'MAPES AVE',
    'MAPLE AVE',
    'MAPLE ST',
    'MAPLETON AVE',
    'MARBLE HILL AVE',
    'MARCUS GARVEY BLVD',
    'MARCY AVE',
    'MARGARET CT',
    'MARGINAL ST  W',
    'MARIA LN',
    'MARION AVE',
    'MARION ST',
    'MARISA CIR',
    'MARISA CT',
    'MARTENSE AVE',
    'MARTENSE ST',
    'MARTIN CT',
    'MARYLAND AVE',
    'MASPETH AVE',
    'MATHEWSON CT',
    'MATHIAS AVE',
    'MAUJER ST',
    'MAYBURY AVE',
    'MC CLEAN AVE',
    'MC KINLEY AVE',
    'MCBRIDE ST',
    'MCGUINNESS BLVD',
    'MEEHAN AVE',
    'MEEKER AVE',
    'MELROSE AVE',
    'MELROSE ST',
    'MENAHAN ST',
    'MENTONE AVE',
    'MERCER ST',
    'MERMAID AVE',
    'MERRIAM AVE',
    'MERRICK BLVD',
    'MERRY AVE',
    'MESEROLE AVE',
    'MESEROLE ST',
    'METROPOLITAN AVE',
    'METROTECH CENTER',
    'MEYER AVE',
    'MICHELLE CT',
    'MIDDAGH ST',
    'MIDDLETOWN RD',
    'MILTON AVE',
    'MINETTA LN',
    'MINNA ST',
    'MINNIEFORD AVE',
    'MITCHEL LN',
    'MOFFAT ST',
    'MOHEGAN AVE',
    'MONROE ST',
    'MONTEREY AVE',
    'MONTGOMERY ST',
    'MONTROSE AVE',
    'MORNINGSTAR RD',
    'MORRIS AVE',
    'MORRIS PARK AVE',
    'MOTT AVE',
    'MOTT ST',
    'MULBERRY ST',
    'MURDOCK AVE',
    'MURRAY ST',
    'MYRTLE AVE',
    'N  12 ST',
    'N  7 ST',
    'N  RAILROAD AVE',
    'NADAL PL',
    'NAGLE AVE',
    'NANSEN ST',
    'NASBY PL',
    'NASH CT',
    'NASHVILLE BLVD',
    'NASSAU AVE',
    'NASSAU ST',
    'NATALIE CT',
    'NAUTILUS AVE',
    'NECKAR AVE',
    'NEEDHAM AVE',
    'NEGUNDO AVE',
    'NELSON AVE',
    'NELSON ST',
    'NEPTON ST',
    'NEPTUNE AVE',
    'NEREID AVE',
    'NETHERLAND AVE',
    'NEUTRAL AVE',
    'NEW DORP LN',
    'NEW DORP PLZ',
    'NEW ENGLAND THRUWAY',
    'NEW ENGLAND THRUWAY SERVICE RD',
    'NEW JERSEY AVE',
    'NEW LOTS AVE',
    'NEW ST',
    'NEW UTRECHT AVE',
    'NEW YORK AVE',
    'NEWBOLD AVE',
    'NEWKIRK AVE',
    'NEWPORT ST',
    'NEWTON ST',
    'NOAH CT',
    'NOBLE ST',
    'NOLL ST',
    'NORFOLK ST',
    'NORMA PL',
    'NORMAN AVE',
    'NORMAN ST',
    'NORTHERN BLVD',
    'NORWOOD AVE',
    'NOSTRAND AVE',
    'NOVA CT',
    'NURGE AVE',
    "O'BRIEN AVE",
    'OAK ST',
    'OCEAN AVE',
    'OCEAN VIEW AVE',
    'OCEANIC AVE',
    'OCEANSIDE AVE',
    'OCEANVIEW AVE',
    'OGDEN AVE',
    'OLMSTEAD AVE',
    'OLYMPIA BLVD',
    'ONDERDONK AVE',
    'ORBIT LN',
    'ORCHARD ST',
    'ORIENTAL CT',
    'ORLOFF AVE',
    'OSGOOD AVE',
    'OSMAN PL',
    'OTIS AVE',
    'PACIFIC ST',
    'PAERDEGAT 12 ST',
    'PALMETTO ST',
    'PARK AVE',
    'PARK AVE S',
    'PARK LN S',
    'PARK PL',
    'PARK ST',
    'PARK TER W',
    'PARKER ST',
    'PARKSIDE PL',
    'PARKVIEW LOOP',
    'PATTERSON AVE',
    'PATTY CT',
    'PAULDING AVE',
    'PEARL ST',
    'PELL PL',
    'PELL ST',
    'PERRY AVE',
    'PERRY ST',
    'PHILIP AVE',
    'PIDGEON MEADOW RD',
    'PIERCE AVE',
    'PILLING ST',
    'PINE ST',
    'PINEHURST AVE',
    'PINEVILLE LN',
    'PINSON ST',
    'PITKIN AVE',
    'PLIMPTON AVE',
    'PLYMOUTH AVE',
    'PLYMOUTH ST',
    'POI CT',
    'POLHEMUS AVE',
    'POPHAM AVE',
    'POPLAR ST',
    'PORT RICHMOND AVE',
    'POST AVE',
    'POST CT',
    'POTTER AVE',
    'POWELL AVE',
    'POWERS ST',
    'PRESIDENT ST',
    'PRESTON CT',
    'PRINCE ST',
    'PROSPECT AVE',
    'PROSPECT PARK W',
    'PROSPECT PL',
    'PROSPECT ST',
    'PULASKI AVE',
    'PULASKI ST',
    'PURCELL ST',
    'PUTNAM AVE',
    'PUTNAM PL',
    'QUEENS',
    'QUEENS PLZ N',
    'QUENCER RD',
    'QUENTIN RD',
    'QUIMBY AVE',
    'QUINCY ST',
    'RADCLIFF AVE',
    'RALPH AVE',
    'RANDALL AVE',
    'RATHBUN AVE',
    'READE ST',
    'RED CEDAR LN',
    'REDFERN AVE',
    'REEVE PL',
    'REGAL',
    'REID AVE',
    'REMSEN ST',
    'RENSSELAER AVE',
    'REON AVE',
    'RESERVOIR OVAL W',
    'REYNOLDS ST',
    'RHINELANDER AVE',
    'RICHARDS ST',
    'RICHARDSON ST',
    'RICHMOND TER',
    'RIDGE ST',
    'RIDGEWOOD AVE',
    'RILEY PL',
    'RIVERDALE AVE',
    'RIVERSIDE DR',
    'RIVINGTON ST',
    'ROBERTS AVE',
    'ROBIN RD',
    'ROCKAWAY AVE',
    'ROCKAWAY BEACH BLVD',
    'ROCKLAND AVE',
    'ROCKWOOD ST',
    'ROEBLING AVE',
    'ROGERS PL',
    'ROMA AVE',
    'ROME AVE',
    'ROOSEVELT AVE',
    'ROSEDALE AVE',
    'ROSEWOOD PL',
    'ROSS ST',
    'ROST PL',
    'RUDD PL',
    'RUSCOE ST',
    'RUTHERFORD CT',
    'RUTHERFORD PL',
    'RUTLAND RD',
    'RUTLEDGE ST',
    'RYER AVE',
    'S  1 ST',
    'S  2 ST',
    'S  3 ST',
    'S  4 ST',
    'S  6 ST',
    'S  8 ST',
    'S  9 ST',
    'S  RAILROAD AVE',
    'SACKET AVE',
    'SACKETT ST',
    'SACKMAN ST',
    'SANDFORD ST',
    'SANDS PL',
    'SANFORD AVE',
    'SARATOGA AVE',
    'SAULTELL AVE',
    'SAVIN CT',
    'SCENIC LN',
    'SCHAEFER ST',
    'SCHERMERHORN ST',
    'SCHLEY AVE',
    'SCHOFIELD ST',
    'SCHOLES ST',
    'SCHOOL ST',
    'SCHURZ AVE',
    'SEDGWICK AVE',
    'SEELEY ST',
    'SENATOR ST',
    'SENECA AVE',
    'SENECA ST',
    'SETH LOOP',
    'SEYMOUR AVE',
    'SHAD CREEK RD',
    'SHAKESPEARE AVE',
    'SHEEPSHEAD BAY RD',
    'SHELDON AVE',
    'SHELLEY AVE',
    'SHERIDAN AVE',
    'SHERIDAN SQUARE',
    'SHERLOCK PL',
    'SHERMAN AVE',
    'SHERMAN ST',
    'SHORE AVE',
    'SHORE PKWY',
    'SIERRA CT',
    'SIGNS RD',
    'SIMONSON PL',
    'SIOUX ST',
    'SITKA ST',
    'SKILLMAN AVE',
    'SKILLMAN ST',
    'SKYLINE DR',
    'SMITH ST',
    'SNYDER AVE',
    'SOMERS ST',
    'SOUTH ST',
    'SPOFFORD AVE',
    'SPRING ST',
    'SPRINGFIELD BLVD',
    'ST ANNS AVE',
    'ST JAMES AVE',
    'ST JOHNS PL',
    'ST MARKS AVE',
    'ST MARYS AVE',
    'ST NICHOLAS AVE',
    'ST RAYMOND AVE',
    'ST THERESA AVE',
    'STACK DR',
    'STAFFORD AVE',
    'STAGG ST',
    'STANHOPE ST',
    'STANLEY AVE',
    'STANTON ST',
    'STARR ST',
    'STATION RD',
    'STEDMAN PL',
    'STEPHEN ST',
    'STERLING PL',
    'STERLING ST',
    'STICKNEY PL',
    'STOCKHOLM ST',
    'STONECREST CT',
    'STORY AVE',
    'STRANG AVE',
    'STRAWBERRY LN',
    'STRYKER CT',
    'STUYVESANT ST',
    'SUFFOLK ST',
    'SULLIVAN PL',
    'SULLIVAN ST',
    'SUMMIT AVE',
    'SUMMIT PL',
    'SUTTER AVE',
    'SUYDAM ST',
    'SWEETWATER AVE',
    'TAFT AVE',
    'TARLTON ST',
    'TARRING ST',
    'TELLER AVE',
    'TEN EYCK',
    'TEN EYCK ST',
    'TENNIS CT',
    'TENNYSON DR',
    'THELMA CT',
    'THOMAS S BOYLAND ST',
    'THOMPSON ST',
    'THURSBY AVE',
    'THWAITES PL',
    'TIEBOUT AVE',
    'TILDEN AVE',
    'TILDEN ST',
    'TINTON AVE',
    'TOMPKINS AVE',
    'TOPPING AVE',
    'TOWNSEND AVE',
    'TRATMAN AVE',
    'TREADWELL AVE',
    'TROUTMAN ST',
    'TROUTVILLE RD',
    'TROY AVE',
    'TRUXTON ST',
    'TUDOR PL',
    'TUSKEGEE AIRMEN WAY',
    'UNDERCLIFF AVE',
    'UNDERHILL AVE',
    'UNION AVE',
    'UNION SQ S',
    'UNION ST',
    'UNION TPKE',
    'UNIVERSITY AVE',
    'UNIVERSITY PL',
    'UTICA AVE',
    'VALENTINE AVE',
    'VAN BRUNT ST',
    'VAN BUREN ST',
    'VAN CORLEAR PL',
    'VAN DOREN ST',
    'VAN DUZER ST',
    'VAN NEST AVE',
    'VAN TUYL ST',
    'VANDERBILT ST',
    'VARICK ST',
    'VERA ST',
    'VERMONT CT',
    'VERNON AVE',
    'VERNON BLVD',
    'VERONA ST',
    'VERONICA PL',
    'VICTORY BLVD',
    'VILLAGE LN',
    'VILLAGE RD N',
    'VISTA PL',
    'VOORHIES AVE',
    'VREELAND ST',
    'VYSE AVE',
    'W  1 ST',
    'W  10 ST',
    'W  101 ST',
    'W  102 ST',
    'W  104 ST',
    'W  108 ST',
    'W  109 ST',
    'W  11 ST',
    'W  111 ST',
    'W  113 ST',
    'W  114 ST',
    'W  115 ST',
    'W  117 ST',
    'W  118 ST',
    'W  119 ST',
    'W  12 RD',
    'W  12 ST',
    'W  121 ST',
    'W  122 ST',
    'W  123 ST',
    'W  126 ST',
    'W  130 ST',
    'W  131 ST',
    'W  136 ST',
    'W  138 ST',
    'W  140 ST',
    'W  141 ST',
    'W  144 ST',
    'W  148 ST',
    'W  15 ST',
    'W  153 ST',
    'W  158 ST',
    'W  159 ST',
    'W  16 ST',
    'W  161 ST',
    'W  162 ST',
    'W  163 ST',
    'W  164 ST',
    'W  165 ST',
    'W  167 ST',
    'W  168 ST',
    'W  169 ST',
    'W  17 ST',
    'W  175 ST',
    'W  176 ST',
    'W  177 ST',
    'W  179 ST',
    'W  18 ST',
    'W  180 ST',
    'W  181 ST',
    'W  183 ST',
    'W  184 ST',
    'W  187 ST',
    'W  188 ST',
    'W  189 ST',
    'W  19 ST',
    'W  21 ST',
    'W  219 ST',
    'W  22 ST',
    'W  225 ST',
    'W  228 ST',
    'W  236 ST',
    'W  24 ST',
    'W  242 ST',
    'W  27 ST',
    'W  28 ST',
    'W  29 ST',
    'W  3 ST',
    'W  30 ST',
    'W  35 ST',
    'W  36 ST',
    'W  37 ST',
    'W  4 ST',
    'W  43 ST',
    'W  46 ST',
    'W  47 ST',
    'W  49 ST',
    'W  55 ST',
    'W  68 ST',
    'W  69 ST',
    'W  7 ST',
    'W  71 ST',
    'W  75 ST',
    'W  8 ST',
    'W  80 ST',
    'W  83 ST',
    'W  9 ST',
    'W  90 ST',
    'W  95 ST',
    'W  98 ST',
    'W  BROADWAY',
    'W  CASWELL AVE',
    'W  END AVE',
    'W  TREMONT AVE',
    'WALKER DR',
    'WALKER ST',
    'WALLABOUT ST',
    'WALLACE AVE',
    'WALLASTON CT',
    'WALTON AVE',
    'WALTON ST',
    'WALWORTH ST',
    'WARREN ST',
    'WASHINGTON AVE',
    'WASHINGTON SQ W',
    'WASHINGTON ST',
    'WATER ST',
    'WATERBURY AVE',
    'WATERSIDE ST',
    'WATKINS AVE',
    'WATKINS ST',
    'WATSON AVE',
    'WAVECREST ST',
    'WAVERLY PL',
    'WEBERS CT',
    'WEBSTER AVE',
    'WEEKS AVE',
    'WEIHER CT',
    'WEIRFIELD ST',
    'WELDON ST',
    'WELLMAN AVE',
    'WENLOCK ST',
    'WENNER PL',
    'WESTCHESTER AVE',
    'WESTPORT LN',
    'WEXFORD TER',
    'WHALLEY AVE',
    'WHITE PLAINS RD',
    'WHITE ST',
    'WHITEHALL PL',
    'WHITELAW ST',
    'WHITMAN DR',
    'WHITNEY AVE',
    'WILBUR ST',
    'WILKINSON AVE',
    'WILLIAM AVE',
    'WILLIAM ST',
    'WILLIAMSON AVE',
    'WILLOUGHBY AVE',
    'WILLOUGHBY ST',
    'WILLOW AVE',
    'WILLOW LN',
    'WILSON AVE',
    'WINEGAR LN',
    'WINTER AVE',
    'WINTHROP ST',
    'WISSMAN AVE',
    'WITHERS ST',
    'WITTHOFF ST',
    'WOODBINE ST',
    'WOODHAVEN CT',
    'WOODPOINT RD',
    'WOODRUFF AVE',
    'WOODRUFF LN',
    'WOODSIDE AVE',
    'WOODWARD AVE',
    'WOODYCREST AVE',
    'WRIGHT AVE',
    'WYCKOFF AVE',
    'WYTHE AVE',
    'WYTHE PL',
    'YOUNG ST',
    'ZULETTE AVE',
    '불쾌지수'
    ]

    columns

    import numpy as np

    vvvv=pd.DataFrame(columns=columns)


    vvvv1=pd.DataFrame(columns=columns)
    vvvv2=pd.DataFrame(columns=columns)
    vvvv3=pd.DataFrame(columns=columns)
    vvvv4=pd.DataFrame(columns=columns)

    STA=pd.read_csv('STATEN1.csv')
    BKL=pd.read_csv('BKLYN1.csv')
    MAN=pd.read_csv('Man1.csv')
    QUEENS1=pd.read_csv('QUEENS1.csv')
    BRO=pd.read_csv('BRONX1.csv')

    count = 0

    arrr=[]
    arrr1=[]
    arrr2=[]
    arrr3=[]
    arrr4=[]

    mcg = folium.plugins.MarkerCluster(control=False) 
    map_osm.add_child(mcg)

    g1= folium.plugins.FeatureGroupSubGroup(mcg , 'Brooklyn')
    map_osm.add_child(g1)
    g2= folium.plugins.FeatureGroupSubGroup(mcg , 'Staten Island')
    map_osm.add_child(g2)
    g3= folium.plugins.FeatureGroupSubGroup(mcg , 'The Bronx')
    map_osm.add_child(g3)
    g4= folium.plugins.FeatureGroupSubGroup(mcg , 'Manhattan')
    map_osm.add_child(g4)
    g5= folium.plugins.FeatureGroupSubGroup(mcg , 'Queens')
    map_osm.add_child(g5)

    # 브룩클린



    for cs in range(len(BKL)):
        temp=blo_temp
        rain=blo_rain
        hum=blo_hum
        speed=blo_speed
        month=now.month
        day=now.day
        hour=now.hour
        street=BKL['street'][cs]
        angry=round((9/5*temp)-(0.55*(1-hum/100)*(9/5*temp-26))+32,2)

        vvvv.loc[count] = np.hstack([np.array([temp,rain,hum,speed,month,day,hour]), np.zeros(1696), np.array([angry])])
        count += 1

        col = BKL['street'][cs]

        vvvv[col][cs] = 1

        vvvv

        arrr.append(street)

    street_fight=np.array(arrr)
    street_fight

    y=model.predict(vvvv)

    y

    street_f=street_fight[y==1]

    street_f



    for i in  range(len(street_f)):
        Latitude=street_info[street_info['FULL_STREE']==street_f[i]]['Latitude_1'].mean()
        Longitude=street_info[street_info['FULL_STREE']==street_f[i]]['Longitude_1'].mean()
        folium.Marker(location=[Latitude,Longitude]).add_to(g1)

     mc.add_child(folium.Marker(location=[Latitude,Longitude]).add_to(map_osm))

    # 스태이튼 아일랜드

    count = 0
    for cs in range(len(STA)):
        temp=sta_temp
        rain=sta_temp
        hum=sta_hum
        speed=sta_speed
        month=now.month
        day=now.day
        hour=now.hour
        street=STA['street'][cs]
        angry=round((9/5*temp)-(0.55*(1-hum/100)*(9/5*temp-26))+32,2)

        vvvv1.loc[count] = np.hstack([np.array([temp,rain,hum,speed,month,day,hour]), np.zeros(1696), np.array([angry])])
        count += 1

        col = STA['street'][cs]

        vvvv1[col][cs] = 1


        arrr1.append(street)

    y1=model.predict(vvvv1)

    street_fight1=np.array(arrr1)
    street_f1=street_fight1[y1==1]

    for i in  range(len(street_f1)):
        Latitude=street_info[street_info['FULL_STREE']==street_f1[i]]['Latitude_1'].mean()
        Longitude=street_info[street_info['FULL_STREE']==street_f1[i]]['Longitude_1'].mean()
        folium.Marker(location=[Latitude,Longitude]).add_to(g2)

    # 브 롱크스

    count = 0
    for cs in range(len(BRO)):
        temp=bro_temp
        rain=bro_rain
        hum=bro_hum
        speed=bro_speed
        month=now.month
        day=now.day
        hour=now.hour
        street=BRO['street'][cs]
        angry=round((9/5*temp)-(0.55*(1-hum/100)*(9/5*temp-26))+32,2)

        vvvv2.loc[count] = np.hstack([np.array([temp,rain,hum,speed,month,day,hour]), np.zeros(1696), np.array([angry])])
        count += 1

        col = BRO['street'][cs]

        vvvv2[col][cs] = 1


        arrr2.append(street)

    y2=model.predict(vvvv2)

    street_fight2=np.array(arrr2)
    street_f2=street_fight2[y2==1]

    for i in  range(len(street_f2)):
        Latitude=street_info[street_info['FULL_STREE']==street_f2[i]]['Latitude_1'].mean()
        Longitude=street_info[street_info['FULL_STREE']==street_f2[i]]['Longitude_1'].mean()
        folium.Marker(location=[Latitude,Longitude]).add_to(g3)

    # 맨하탄포티지

    street_fight2

    y2==1

    count = 0
    for cs in range(len(MAN)):
        temp=man_temp
        rain=man_rain
        hum=man_hum
        speed=man_speed
        month=now.month
        day=now.day
        hour=now.hour
        street=MAN['street'][cs]
        angry=round((9/5*temp)-(0.55*(1-hum/100)*(9/5*temp-26))+32,2)

        vvvv3.loc[count] = np.hstack([np.array([temp,rain,hum,speed,month,day,hour]), np.zeros(1696), np.array([angry])])
        count += 1

        col = MAN['street'][cs]

        vvvv3[col][cs] = 1


        arrr3.append(street)

    y3=model.predict(vvvv3)


    street_fight3=np.array(arrr3)
    street_f3=street_fight3[y3==1]


    for i in  range(len(street_f3)):
        Latitude=street_info[street_info['FULL_STREE']==street_f3[i]]['Latitude_1'].mean()
        Longitude=street_info[street_info['FULL_STREE']==street_f3[i]]['Longitude_1'].mean()
        folium.Marker(location=[Latitude,Longitude]).add_to(g4)

    # 퀸즈 

    count = 0
    for cs in range(len(QUEENS1)):
        temp=que_temp
        rain=que_rain
        hum=que_hum
        speed=que_speed
        month=now.month
        day=now.day
        hour=now.hour
        street=QUEENS1['street'][cs]
        angry=round((9/5*temp)-(0.55*(1-hum/100)*(9/5*temp-26))+32,2)

        vvvv4.loc[count] = np.hstack([np.array([temp,rain,hum,speed,month,day,hour]), np.zeros(1696), np.array([angry])])
        count += 1

        col = QUEENS1['street'][cs]

        vvvv4[col][cs] = 1


        arrr4.append(street)

    y4=model.predict(vvvv4)

    street_fight4=np.array(arrr4)
    street_f4=street_fight4[y4==1]

    for i in  range(len(street_f4)):
        Latitude=street_info[street_info['FULL_STREE']==street_f4[i]]['Latitude_1'].mean()
        Longitude=street_info[street_info['FULL_STREE']==street_f4[i]]['Longitude_1'].mean()
        folium.Marker(location=[Latitude,Longitude]).add_to(g5)

    map_osm

    folium.LayerControl(collapsed=False).add_to(map_osm)

    map_osm.save('map.html')
    time.sleep(3600)
# Out:
#   File "<tokenize>", line 1930
#     mc.add_child(folium.Marker(location=[Latitude,Longitude]).add_to(map_osm))
#     ^
# IndentationError: unindent does not match any outer indentation level
